# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import google.generativeai as genai

# Configure Gemini API configuration
genai.configure(api_key="AIzaSyB-klr5sJ3Jh2_4-hOMs370Xw1a6NNoUo8")
#
model = genai.GenerativeModel("gemini-2.0-flash")

# --- Auto Famous Thing using AI ---
def get_famous_thing(place):
    #to genreate the content from model
    reply = f"Tell one famous thing about {place} in one short line with emoji."
    response = model.generate_content(reply)
    return response.text

# --- Travel Planner Function --
def travel_planner(destination, days, interests):
    reply = f"""
    Create a medium-length, attractive {days}-day travel plan for {destination} with emojis.

    STYLE RULES:
    - Short intro (2 lines)
    - Day-wise:
        🌅 Morning: max 3 short lines
        🌞 Afternoon:max 3 short lines
        🌙 Evening: max 3 short lines
    - 3–4 local foods with emojis
    - Use only famous places
    - No long paragraphs
    - Medium content (not too long, not too short)
    - Clean, easy-to-read formatting
    - Interests: {interests}
   Make the output colourful, engaging and suitable for a student project.
    """
    response = model.generate_content(reply)
    return response.text
    
# --- PREDEFINED INPUTS (Change here as you like) ---
place = "Coimbatore"
days = "3"
interests = "Tourist Place"

# --- OUTPUT ---
print("\n--- Famous Thing ---")
print(get_famous_thing(place))

print("\n--- Your AI Travel Plan ---\n")
print(travel_planner(place, days, interests))
# Out:
# --- Famous Thing ---
# Coimbatore is famous for its textile industry, earning it the nickname "Manchester of South India." 🧵
#
#
# --- Your AI Travel Plan ---
#
# ## Coimbatore in 3 Days: A Whirlwind Tour! 🚀
#
# Explore the Manchester of South India! Get ready for temples, hills, and delicious food! 😋
#
# ---
#
# **Day 1: Spiritual Start & City Buzz 🕉️**
#
# 🌅 Morning: Visit the iconic Marudamalai Murugan Temple. Enjoy the serene atmosphere and panoramic views. 🙏
# 🌞 Afternoon: Explore the GD Naidu Museum, a treasure trove of innovation and technology. ⚙️
# 🌙 Evening: Stroll through RS Puram, a vibrant shopping district. Grab dinner at a local restaurant. 🛍️
#
# ---
#
# **Day 2: Nature's Embrace & Artistic Flair 🏞️**
#
# 🌅 Morning: Head to the refreshing Siruvani Waterfalls. Enjoy the scenic beauty and cool waters. 💧
# 🌞 Afternoon: Immerse yourself in art at the Gass Forest Museum. Discover a unique collection of flora and fauna. 🌳
# ...

# %%
import google.generativeai as genai

# Configure Gemini API configuration
genai.configure(api_key="AIzaSyB-klr5sJ3Jh2_4-hOMs370Xw1a6NNoUo8")
#
model = genai.GenerativeModel("gemini-2.0-flash")

# --- Auto Famous Thing using AI ---
def get_famous_thing(place):
    #to genreate the content from model
    reply = f"Tell one famous thing about {place} in one short line with emoji."
    response = model.generate_content(reply)
    return response.text

# --- Travel Planner Function --
def travel_planner(destination, days, interests):
    reply = f"""
    Create a medium-length, attractive {days}-day travel plan for {destination} with emojis.

    STYLE RULES:
    - Short intro (2 lines)
    - Day-wise:
        🌅 Morning: max 3 short lines
        🌞 Afternoon:max 3 short lines
        🌙 Evening: max 3 short lines
    - 3–4 local foods with emojis
    - Use only famous places
    - No long paragraphs
    - Medium content (not too long, not too short)
    - Clean, easy-to-read formatting
    - Interests: {interests}
   Make the output colourful, engaging and suitable for a student project.
    """
    response = model.generate_content(reply)
    return response.text

# --- PREDEFINED INPUTS (Change here as you like) ---
place = "Tenkasi"
days = "2"
interests = "Visiting"

# --- OUTPUT ---
print("\n--- Famous Thing ---")
print(get_famous_thing(place))

print("\n--- Your AI Travel Plan ---\n")
print(travel_planner(place, days, interests))
# Out:
# --- Famous Thing ---
# Tenkasi is famous for its breathtaking Courtallam Falls 🏞️.
#
#
# --- Your AI Travel Plan ---
#
# ✨Tenkasi Calling!✨ Get ready for a quick trip filled with temples, waterfalls, and scenic beauty! Here's your 2-day itinerary:
#
# **Day 1: Temples & Waterfalls 🏞️**
#
# 🌅 **Morning:**
# *   Arrive at Tenkasi and check in. 🧳
# *   Visit the iconic Kasi Viswanathar Temple. 🙏
# *   Marvel at the stunning architecture.
#
# 🌞 **Afternoon:**
# *   Head to Courtallam Falls (Main Falls). 🌊
# *   Enjoy a refreshing dip in the cascading water.
# *   Lunch with a view!
#
# 🌙 **Evening:**
# *   Explore the Five Falls (Aintharuvi). 🏞️
# *   Relax and enjoy the natural beauty.
# *   Dinner at a local restaurant. 🍽️
#
# **Day 2: Scenery & Spiritual Sojourn ⛰️**
#
# 🌅 **Morning:**
# *   Visit Thirumalai Kovil 🛕
# *   Enjoy the panoramic views from the hilltop. 🤩
# *   Breathe in the fresh air.
#
# 🌞 **Afternoon:**
# *   Explore Shenbaga Falls. 🌳
# ...
